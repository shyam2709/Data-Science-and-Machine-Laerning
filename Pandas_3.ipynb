# %% [markdown]
# <a href="https://colab.research.google.com/github/shyam2709/Data-Science-and-Machine-Laerning/blob/main/Pandas_3.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Pandas 3")
# Out:
# Welcome to Pandas 3

# %%
import pandas as pd

# %%
url = 'https://raw.githubusercontent.com/shyam2709/Data-Science-and-Machine-Laerning/main/gapminder.csv'

# %%
df = pd.read_csv(url)

# %%
df
# Out:
#           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]

# %%
df.describe
# Out:
# <bound method NDFrame.describe of           country  year  population continent  life_exp     gdp_cap
# 0     Afghanistan  1952     8425333      Asia    28.801  779.445314
# 1     Afghanistan  1957     9240934      Asia    30.332  820.853030
# 2     Afghanistan  1962    10267083      Asia    31.997  853.100710
# 3     Afghanistan  1967    11537966      Asia    34.020  836.197138
# 4     Afghanistan  1972    13079460      Asia    36.088  739.981106
# ...           ...   ...         ...       ...       ...         ...
# 1699     Zimbabwe  1987     9216418    Africa    62.351  706.157306
# 1700     Zimbabwe  1992    10704340    Africa    60.377  693.420786
# 1701     Zimbabwe  1997    11404948    Africa    46.809  792.449960
# 1702     Zimbabwe  2002    11926563    Africa    39.989  672.038623
# 1703     Zimbabwe  2007    12311143    Africa    43.487  469.709298
#
# [1704 rows x 6 columns]>

# %%
df['life_exp'].sum()
# Out:
# 101344.44467999999

# %%
df['life_exp'].mean()
# Out:
# 59.474439366197174

# %%
df['life_exp'].min()
# Out:
# 23.599

# %%
df['life_exp'].mean()
# Out:
# 59.474439366197174

# %%
df['life_exp'].count()
# Out:
# 1704

# %%
df2=df[['year','population','life_exp']]

# %%
df2
# Out:
#       year  population  life_exp
# 0     1952     8425333    28.801
# 1     1957     9240934    30.332
# 2     1962    10267083    31.997
# 3     1967    11537966    34.020
# 4     1972    13079460    36.088
# ...    ...         ...       ...
# 1699  1987     9216418    62.351
# 1700  1992    10704340    60.377
# 1701  1997    11404948    46.809
# 1702  2002    11926563    39.989
# 1703  2007    12311143    43.487
#
# [1704 rows x 3 columns]

# %%
df.sort_values(["year"])
# Out:
#                  country  year  population continent  life_exp       gdp_cap
# 0            Afghanistan  1952     8425333      Asia    28.801    779.445314
# 528               France  1952    42459667    Europe    67.410   7029.809327
# 540                Gabon  1952      420702    Africa    37.003   4293.476475
# 1656  West Bank and Gaza  1952     1030585      Asia    43.160   1515.592329
# 552               Gambia  1952      284320    Africa    30.000    485.230659
# ...                  ...   ...         ...       ...       ...           ...
# 1127               Niger  2007    12894865    Africa    56.867    619.676892
# 1139             Nigeria  2007   135031164    Africa    46.859   2013.977305
# 1151              Norway  2007     4627926    Europe    80.196  49357.190170
# 1175            Pakistan  2007   169270617      Asia    65.483   2605.947580
# 1703            Zimbabwe  2007    12311143    Africa    43.487    469.709298
#
# [1704 rows x 6 columns]

# %%
df.sort_values(["year"],ascending=False)
# Out:
#                 country  year  population continent  life_exp        gdp_cap
# 1703           Zimbabwe  2007    12311143    Africa    43.487     469.709298
# 491   Equatorial Guinea  2007      551201    Africa    51.579   12154.089750
# 515            Ethiopia  2007    76511887    Africa    52.947     690.805576
# 527             Finland  2007     5238460    Europe    79.313   33207.084400
# 539              France  2007    61083916    Europe    80.657   30470.016700
# ...                 ...   ...         ...       ...       ...            ...
# 1116              Niger  1952     3379468    Africa    37.444     761.879376
# 1128            Nigeria  1952    33119096    Africa    36.324    1077.281856
# 1140             Norway  1952     3327728    Europe    72.670   10095.421720
# 1152               Oman  1952      507833      Asia    37.578    1828.230307
# 852              Kuwait  1952      160000      Asia    55.565  108382.352900
#
# [1704 rows x 6 columns]

# %%
df.sort_values(['year','population'],ascending = False).head(5)
# Out:
#             country  year  population continent  life_exp       gdp_cap
# 299           China  2007  1318683096      Asia    72.961   4959.114854
# 707           India  2007  1110396331      Asia    64.698   2452.210407
# 1619  United States  2007   301139947  Americas    78.242  42951.653090
# 719       Indonesia  2007   223547000      Asia    70.650   3540.651564
# 179          Brazil  2007   190010647  Americas    72.390   9065.800825

# %%
df.sort_values(['year','population'],ascending = [False,True]).head(5)
# Out:
#                     country  year  population continent  life_exp  \
# 1307  Sao Tome and Principe  2007      199579    Africa    65.528
# 695                 Iceland  2007      301931    Europe    81.757
# 431                Djibouti  2007      496374    Africa    54.791
# 491       Equatorial Guinea  2007      551201    Africa    51.579
# 1019             Montenegro  2007      684736    Europe    74.543
#
#            gdp_cap
# 1307   1598.435089
# 695   36180.789190
# 431    2082.481567
# 491   12154.089750
# 1019   9253.896111

# %%
x=pd.DataFrame({"A":[10,20],"B":[30,40]})
y=pd.DataFrame({"A":[50,60],"D":[70,80]})

# %%
x
# Out:
#     A   B
# 0  10  30
# 1  20  40

# %%
y
# Out:
#     A   D
# 0  50  70
# 1  60  80

# %%
pd.concat([x,y])
# Out:
#     A     B     D
# 0  10  30.0   NaN
# 1  20  40.0   NaN
# 0  50   NaN  70.0
# 1  60   NaN  80.0

# %%
pd.concat([x,y],axis=1)
# Out:
#     A   B   A   D
# 0  10  30  50  70
# 1  20  40  60  80

# %%
pd.concat([x,y],ignore_index=True)             #it will ignore index and gives own index
# Out:
#     A     B     D
# 0  10  30.0   NaN
# 1  20  40.0   NaN
# 2  50   NaN  70.0
# 3  60   NaN  80.0

# %%
users = pd.DataFrame({"userid":[1,2,3],"name":["Shyam","Ram","Hari"]})

# %%
users
# Out:
#    userid   name
# 0       1  Shyam
# 1       2    Ram
# 2       3   Hari

# %%
msgs=pd.DataFrame({"userid":[1,1,2,4],"msg":["Hmmm","accha","thik he","nice"]})
msgs
# Out:
#    userid      msg
# 0       1     Hmmm
# 1       1    accha
# 2       2  thik he
# 3       4     nice

# %%
users.merge(msgs)
# Out:
#    userid   name      msg
# 0       1  Shyam     Hmmm
# 1       1  Shyam    accha
# 2       2    Ram  thik he

# %%
users.merge(msgs,on="userid")
# Out:
#    userid   name      msg
# 0       1  Shyam     Hmmm
# 1       1  Shyam    accha
# 2       2    Ram  thik he

# %%
users.merge(msgs,on="userid",how="left")
# Out:
#    userid   name      msg
# 0       1  Shyam     Hmmm
# 1       1  Shyam    accha
# 2       2    Ram  thik he
# 3       3   Hari      NaN

# %%
users.merge(msgs,on="userid",how="right")
# Out:
#    userid   name      msg
# 0       1  Shyam     Hmmm
# 1       1  Shyam    accha
# 2       2    Ram  thik he
# 3       4    NaN     nice

# %%
users.merge(msgs,on="userid",how="outer")
# Out:
#    userid   name      msg
# 0       1  Shyam     Hmmm
# 1       1  Shyam    accha
# 2       2    Ram  thik he
# 3       3   Hari      NaN
# 4       4    NaN     nice

# %%
users.rename(columns={"userid":"id"},inplace=True)

# %%
users.merge(msgs,left_on="id",right_on="userid")
# Out:
#    id   name  userid      msg
# 0   1  Shyam       1     Hmmm
# 1   1  Shyam       1    accha
# 2   2    Ram       2  thik he

# %%
pd.merge?

# %%
df=pd.DataFrame({"name":["A","B","C","D","E"],"income":["low","high","medium","medium","medium"]})
df
# Out:
#   name  income
# 0    A     low
# 1    B    high
# 2    C  medium
# 3    D  medium
# 4    E  medium

# %%
medium_income = df[df["income"]=="medium"]
medium_income
    ### STEP 2: calculate count of medium income employees
medium_income_count = len(medium_income)
medium_income_count
    ### STEP 3: calculate percentage of medium income employees
# result = (medium_income_count/pd["income"].nunique)*100
# return result
result = (medium_income_count/len(df.columns))*100
result
len(df.columns)
# Out:
# 2

# %%
df=pd.DataFrame({"name":["A","B","C","D","E","G"],"gender":["M","F","M","F","M","F"],"income":[10000,20000,30000,40000,50000,60000]})
df
# Out:
#   name gender  income
# 0    A      M   10000
# 1    B      F   20000
# 2    C      M   30000
# 3    D      F   40000
# 4    E      M   50000
# 5    G      F   60000

# %%
###  1 : filter the income of male records
male_income = df[df["gender"]=="M"]
### STEP 2: Filter the income of female records
female_income = df[df["gender"]=="F"]
### STEP3: calculate the median of income
male_median = male_income.median()
female_median = female_income.median()
### STEP 4: calculate absolute difference in median income of male and female
result = sub["male_median","female_median"]
return result
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:6: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   import sys

# %%
customer=pd.DataFrame({'cust_id': [101, 102, 103, 104], 'name': ['rick', 'morty', 'pickle', 'jerry']})
orders=pd.DataFrame({'order_id':['OR1', 'OR3', 'OR23', 'OR42'], 'cust_id' : [102, 105, 101, 102], 'amount': [1200, 650, 120, 989]})

# %%
customer
# Out:
#    cust_id    name
# 0      101    rick
# 1      102   morty
# 2      103  pickle
# 3      104   jerry

# %%
merged_df=customer.merge(orders,on="cust_id",how="outer")
## STEP 2: calculate sum of amount for given name
sum_of_amount=merged_df[merged_df["name"]=="morty"]
sum_amount = sum_of_amount["amount"].sum()
print(merged_df)
print(sum_amount)
# Out:
#    cust_id    name order_id  amount
# 0      101    rick     OR23   120.0
# 1      102   morty      OR1  1200.0
# 2      102   morty     OR42   989.0
# 3      103  pickle      NaN     NaN
# 4      104   jerry      NaN     NaN
# 5      105     NaN      OR3   650.0
# 2189.0

# %%
df=pd.DataFrame({'name':['a','b','c','d','e'],'jan_payment':[10,12,13,14,15],'feb_payment':[11,11,11,11,11],'mar_payment':[100,120,130,130,140]})

# %%
df
# Out:
#   name  jan_payment  feb_payment  mar_payment
# 0    a           10           11          100
# 1    b           12           11          120
# 2    c           13           11          130
# 3    d           14           11          130
# 4    e           15           11          140

# %%
df["avg_payment"] = df.mean(axis=0)
    # drop the columns 'jan_payment' and 'feb_payment'
df.drop(["jan_payment","feb_payment"],axis=0)
    # Don't modify this line of code
df
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   """Entry point for launching an IPython kernel.
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-90-98a25718a888> in <module>
#       1 df["avg_payment"] = df.mean(axis=0)
#       2     # drop the columns 'jan_payment' and 'feb_payment'
# ----> 3 df.drop(["jan_payment","feb_payment"],axis=0)
#       4     # Don't modify this line of code
#       5 df
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
# ...

# %%
x=pd.DataFrame({'name': ['Elon', 'Jeff', 'Bill', 'Falguni',], 'gender': ['M', 'F', 'M', 'F',], 'income': [53000, 28000, 25000, 44000]})
x
# Out:
#       name gender  income
# 0     Elon      M   53000
# 1     Jeff      F   28000
# 2     Bill      M   25000
# 3  Falguni      F   44000

# %%
max_income = x[x["income"] == x.income.max()]
max_income
# Out:
#    name gender  income
# 0  Elon      M   53000

# %%
import pandas as pd  
df = pd.DataFrame({'dates':["2015-12-06", "2011-12-27", "2015-09-07", "2012-12-21", "2020-02-13"], 'RID':[498, 721, 375, 464, 813], 'Phy':[22, 45, 1, 65, 22], 'Chem':[52, 56, 32, 50, 24], 'Math':[63, 37, 68, 62, 43]})

# %%
df
# Out:
#         dates  RID  Phy  Chem  Math
# 0  2015-12-06  498   22    52    63
# 1  2011-12-27  721   45    56    37
# 2  2015-09-07  375    1    32    68
# 3  2012-12-21  464   65    50    62
# 4  2020-02-13  813   22    24    43

# %%
    filtered_df = df[df["dates"] > "2014-05-01"]
    # Compute the avg column based on avg of Phy, Chem and Math columns
    filtered_df["avg"] = df[["Phy","Chem","Math"]].mean(axis=1)
    # Sort the values as per avg, and select only the RID column
    a=filtered_df.sort_values(by='avg')["RID"]
    a
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   This is separate from the ipykernel package so we can avoid doing imports until
# 4    813
# 2    375
# 0    498
# Name: RID, dtype: int64

# %%
import pandas as pd  
df1 = pd.DataFrame({"name": ['tobey', 'peter', 'chris', 'pratt'],'chem_score':[10, 9, 8, 7], 'phy_score':[7, 8, 9, 10], 'Hindi_score':[9, 9, 9, 9]})  
df2 = pd.DataFrame({"name": ['chris', 'pratt', 'andrew', 'tom'],'chem_score':[10, 10, 10, 9], 'maths_score':[6, 6, 7, 9], 'eng_score':[9, 10, 10, 9]})

# %%
df1
# Out:
#     name  chem_score  phy_score  Hindi_score
# 0  tobey          10          7            9
# 1  peter           9          8            9
# 2  chris           8          9            9
# 3  pratt           7         10            9

# %%
df2
# Out:
#      name  chem_score  maths_score  eng_score
# 0   chris          10            6          9
# 1   pratt          10            6         10
# 2  andrew          10            7         10
# 3     tom           9            9          9

# %%
ans=[]
    # YOUR CODE GOES HERE
ans=df1.df2[["chem_score"]].mean(axis=1)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-106-3e645bcfe9b4> in <module>
#       1 ans=[]
#       2     # YOUR CODE GOES HERE
# ----> 3 ans=df1.df2[["chem_score"]].mean(axis=1)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'df2'

# %%
df1 = pd.DataFrame({'name': ['Jack','Ryan','Chris','Sam'],
'rank': [1, 2, 3, 4]})
df2 = pd.DataFrame({'name': ['Ryan', 'Sam', 'Chris', 'Jack'],
'rank': [3, 1, 4, 2]})

print(pd.merge(df1,df2, on="name"))
# Out:
#     name  rank_x  rank_y
# 0   Jack       1       2
# 1   Ryan       2       3
# 2  Chris       3       4
# 3    Sam       4       1

# %%
ds3=pd.DataFrame({"cust_id":[101,102,103,104],"name":['A','B','C','D']})
ds3
# Out:
#    cust_id name
# 0      101    A
# 1      102    B
# 2      103    C
# 3      104    D

# %%
ds3.isin([101, 102, 120])
# Out:
#    cust_id   name
# 0     True  False
# 1     True  False
# 2    False  False
# 3    False  False

# %%
ds3.isin({'cust_id': [101, 102]})
# Out:
#    cust_id   name
# 0     True  False
# 1     True  False
# 2    False  False
# 3    False  False

# %%
ds3.isin(df.cust_id)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-118-76581470d360> in <module>
# ----> 1 ds3.isin(df.cust_id)
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in __getattr__(self, name)
#    5485         ):
#    5486             return self[name]
# -> 5487         return object.__getattribute__(self, name)
#    5488
#    5489     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'cust_id'

# %%
ds3.name.isin('A')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-119-99ccc658f581> in <module>
# ----> 1 ds3.name.isin('A')
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/series.py in isin(self, values)
#    5023         dtype: bool
#    5024         """
# -> 5025         result = algorithms.isin(self._values, values)
#    5026         return self._constructor(result, index=self.index).__finalize__(
#    5027             self, method="isin"
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/algorithms.py in isin(comps, values)
#     458     if not is_list_like(values):
#     459         raise TypeError(
# --> 460             "only list-like objects are allowed to be passed "
#     461             f"to isin(), you passed a [{type(values).__name__}]"
#     462         )
#
# TypeError: only list-like objects are allowed to be passed to isin(), you passed a [str]
