# %% [markdown]
# <a href="https://colab.research.google.com/github/shyam2709/Data-Science-and-Machine-Laerning/blob/main/Pandas_5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
print("Welcome to Pandas 5")
# Out:
# Welcome to Pandas 5

# %%
# !gdown 1plG9wcsIXbDKXPPZd1NfOALaoc6I7Yiq
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1plG9wcsIXbDKXPPZd1NfOALaoc6I7Yiq
# To: /content/directors.csv
# 100% 65.4k/65.4k [00:00<00:00, 46.0MB/s]

# %%
# !gdown 13bZ0iUvZd7KgSFUgW5p5BhYt4KZ8kS8r
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=13bZ0iUvZd7KgSFUgW5p5BhYt4KZ8kS8r
# To: /content/movies.csv
# 100% 112k/112k [00:00<00:00, 56.7MB/s]

# %%
import pandas as pd
import numpy as np
movies=pd.read_csv("movies.csv", index_col = 0)
directors=pd.read_csv("directors.csv", index_col = 0)

# %%
data=movies.merge(directors, how='left',left_on = 'director_id',right_on='id')

# %%
data
# Out:
#        id_x     budget  popularity     revenue  \
# 0     43597  237000000         150  2787965087
# 1     43598  300000000         139   961000000
# 2     43599  245000000         107   880674609
# 3     43600  250000000         112  1084939099
# 4     43602  258000000         115   890871626
# ...     ...        ...         ...         ...
# 1460  48363          0           3      321952
# 1461  48370      27000          19     3151130
# 1462  48375          0           7           0
# 1463  48376          0           3           0
# 1464  48395     220000          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data['budget']=(data['budget']/1000000).round(2)
data
# Out:
#        id_x  budget  popularity     revenue  \
# 0     43597  237.00         150  2787965087
# 1     43598  300.00         139   961000000
# 2     43599  245.00         107   880674609
# 3     43600  250.00         112  1084939099
# 4     43602  258.00         115   890871626
# ...     ...     ...         ...         ...
# 1460  48363    0.00           3      321952
# 1461  48370    0.03          19     3151130
# 1462  48375    0.00           7           0
# 1463  48376    0.00           3           0
# 1464  48395    0.22          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
def calc_exp(x):
  x=x-x.mean()
  return x
data.groupby("director_name")["budget"].transform(calc_exp)
# Out:
# 0       130.300000
# 1       141.857143
# 2       150.142857
# 3       124.375000
# 4       174.004545
#            ...
# 1460    -47.478947
# 1461    -11.976667
# 1462    -21.700000
# 1463    -10.890909
# 1464    -31.168750
# Name: budget, Length: 1465, dtype: float64

# %%
data.loc[data["director_name"]=="James Cameron",["budget"]].mean()
# Out:
# budget    106.7
# dtype: float64

# %%
def calc_risky(x):
  x["risky"]=(x["budget"]-x["revenue"].mean())>=0
  return x
data_risky=data.groupby("director_name").apply(calc_risky)

# %%
data_risky
# Out:
#        id_x  budget  popularity     revenue  \
# 0     43597  237.00         150  2787965087
# 1     43598  300.00         139   961000000
# 2     43599  245.00         107   880674609
# 3     43600  250.00         112  1084939099
# 4     43602  258.00         115   890871626
# ...     ...     ...         ...         ...
# 1460  48363    0.00           3      321952
# 1461  48370    0.03          19     3151130
# 1462  48375    0.00           7           0
# 1463  48376    0.00           3           0
# 1464  48395    0.22          14     2040920
#
#                                          title  vote_average  vote_count  \
# 0                                       Avatar           7.2       11800
# 1     Pirates of the Caribbean: At World's End           6.9        4500
# 2                                      Spectre           6.3        4466
# 3                        The Dark Knight Rises           7.6        9106
# ...

# %%
data.loc[:,["revenue","budget"]]
# Out:
#          revenue  budget
# 0     2787965087  237.00
# 1      961000000  300.00
# 2      880674609  245.00
# 3     1084939099  250.00
# 4      890871626  258.00
# ...          ...     ...
# 1460      321952    0.00
# 1461     3151130    0.03
# 1462           0    0.00
# 1463           0    0.00
# 1464     2040920    0.22
#
# [1465 rows x 2 columns]

# %%
data.loc[:,["revenue","budget"]].apply(np.sum,axis=0)
# Out:
# revenue    2.098670e+11
# budget     7.035362e+04
# dtype: float64

# %%
data.loc[:,["revenue","budget"]].apply(np.max,axis=0)
# Out:
# revenue    2.787965e+09
# budget     3.800000e+02
# dtype: float64

# %%
data.loc[:,["revenue","budget","vote_average"]].apply(np.mean,axis=0)
# Out:
# revenue         1.432539e+08
# budget          4.802295e+01
# vote_average    6.368191e+00
# dtype: float64

# %%
data.loc[:,["revenue","budget","vote_average"]].apply(np.mean,axis=1)
# Out:
# 0       9.293218e+08
# 1       3.203334e+08
# 2       2.935583e+08
# 3       3.616465e+08
# 4       2.969573e+08
#             ...
# 1460    1.073200e+05
# 1461    1.050379e+06
# 1462    2.000000e+00
# 1463    2.133333e+00
# 1464    6.803089e+05
# Length: 1465, dtype: float64

# %%
# !gdown 1q6zmUg6RWc61OhpiRu_x_kvzxavLZNQY
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1q6zmUg6RWc61OhpiRu_x_kvzxavLZNQY
# To: /content/Pfizer_1.csv
# 100% 1.51k/1.51k [00:00<00:00, 2.16MB/s]

# %%
df=pd.read_csv("Pfizer_1.csv")
df
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      NaN     17.0
# 3   15-10-2020      docetaxel injection     Pressure      NaN     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      NaN
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      NaN
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
pd.Series([1,np.nan,2,np.nan,3,np.nan,4,None])
# Out:
# 0    1.0
# 1    NaN
# 2    2.0
# 3    NaN
# 4    3.0
# 5    NaN
# 6    4.0
# 7    NaN
# dtype: float64

# %%
type(None)
# Out:
# NoneType

# %%
type(np.nan)
# Out:
# float

# %%
df.isna()    #True value means, values are missing.
# Out:
#      Date  Drug_Name  Parameter  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  \
# 0   False      False      False    False    False     True    False    False
# 1   False      False      False    False    False     True    False    False
# 2   False      False      False     True    False    False     True    False
# 3   False      False      False     True    False    False     True    False
# 4   False      False      False    False     True     True    False     True
# 5   False      False      False    False     True     True    False     True
# 6   False      False      False    False    False    False    False    False
# 7   False      False      False    False    False    False    False    False
# 8   False      False      False    False    False     True    False    False
# 9   False      False      False    False    False     True    False    False
# 10  False      False      False    False    False    False     True    False
# ...

# %%
df.isnull()    #same as isna
# Out:
#      Date  Drug_Name  Parameter  1:30:00  2:30:00  3:30:00  4:30:00  5:30:00  \
# 0   False      False      False    False    False     True    False    False
# 1   False      False      False    False    False     True    False    False
# 2   False      False      False     True    False    False     True    False
# 3   False      False      False     True    False    False     True    False
# 4   False      False      False    False     True     True    False     True
# 5   False      False      False    False     True     True    False     True
# 6   False      False      False    False    False    False    False    False
# 7   False      False      False    False    False    False    False    False
# 8   False      False      False    False    False     True    False    False
# 9   False      False      False    False    False     True    False    False
# 10  False      False      False    False    False    False     True    False
# ...

# %%
df.isna().sum()         #it gives sum of missing values at each columns
# Out:
# Date         0
# Drug_Name    0
# Parameter    0
# 1:30:00      2
# 2:30:00      2
# 3:30:00      6
# 4:30:00      4
# 5:30:00      2
# 6:30:00      0
# 7:30:00      2
# 8:30:00      4
# 9:30:00      2
# 10:30:00     0
# 11:30:00     2
# 12:30:00     0
# dtype: int64

# %%
df.info()       #it gives non null values, means values with any data
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18 entries, 0 to 17
# Data columns (total 15 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Date       18 non-null     object
#  1   Drug_Name  18 non-null     object
#  2   Parameter  18 non-null     object
#  3   1:30:00    16 non-null     float64
#  4   2:30:00    16 non-null     float64
#  5   3:30:00    12 non-null     float64
#  6   4:30:00    14 non-null     float64
#  7   5:30:00    16 non-null     float64
#  8   6:30:00    18 non-null     int64
#  9   7:30:00    16 non-null     float64
#  10  8:30:00    14 non-null     float64
#  11  9:30:00    16 non-null     float64
#  12  10:30:00   18 non-null     int64
#  13  11:30:00   16 non-null     float64
#  14  12:30:00   18 non-null     int64
# dtypes: float64(9), int64(3), object(3)
# memory usage: 2.2+ KB

# %%
df.isna().count()
# Out:
# Date         18
# Drug_Name    18
# Parameter    18
# 1:30:00      18
# 2:30:00      18
# 3:30:00      18
# 4:30:00      18
# 5:30:00      18
# 6:30:00      18
# 7:30:00      18
# 8:30:00      18
# 9:30:00      18
# 10:30:00     18
# 11:30:00     18
# 12:30:00     18
# dtype: int64

# %%
df.fillna(0)
# Out:
#           Date                Drug_Name    Parameter  1:30:00  2:30:00  \
# 0   15-10-2020  diltiazem hydrochloride  Temperature     23.0     22.0
# 1   15-10-2020  diltiazem hydrochloride     Pressure     12.0     13.0
# 2   15-10-2020      docetaxel injection  Temperature      0.0     17.0
# 3   15-10-2020      docetaxel injection     Pressure      0.0     22.0
# 4   15-10-2020   ketamine hydrochloride  Temperature     24.0      0.0
# 5   15-10-2020   ketamine hydrochloride     Pressure      8.0      0.0
# 6   16-10-2020  diltiazem hydrochloride  Temperature     34.0     35.0
# 7   16-10-2020  diltiazem hydrochloride     Pressure     18.0     19.0
# 8   16-10-2020      docetaxel injection  Temperature     46.0     47.0
# 9   16-10-2020      docetaxel injection     Pressure     23.0     24.0
# 10  16-10-2020   ketamine hydrochloride  Temperature      8.0      9.0
# 11  16-10-2020   ketamine hydrochloride     Pressure     12.0     12.0
# ...

# %%
df1=pd.melt(df,id_vars=["Date","Drug_Name","Parameter"],).head(10)

# %%
df2=df.dropna()           #it drops all the rows which have even 1 Na value

# %%
df2
# Out:
#           Date               Drug_Name    Parameter  1:30:00  2:30:00  \
# 14  17-10-2020     docetaxel injection  Temperature     12.0     13.0
# 15  17-10-2020     docetaxel injection     Pressure     20.0     22.0
# 16  17-10-2020  ketamine hydrochloride  Temperature     13.0     14.0
# 17  17-10-2020  ketamine hydrochloride     Pressure      8.0      9.0
#
#     3:30:00  4:30:00  5:30:00  6:30:00  7:30:00  8:30:00  9:30:00  10:30:00  \
# 14     14.0     15.0     16.0       17     18.0     19.0     20.0        21
# 15     22.0     22.0     22.0       23     25.0     26.0     27.0        28
# 16     15.0     16.0     17.0       18     19.0     20.0     21.0        22
# 17     10.0     11.0     11.0       12     12.0     11.0     12.0        13
#
#     11:30:00  12:30:00
# 14      22.0        23
# 15      29.0        28
# 16      23.0        24
# 17      14.0        15

# %%
pd.melt(df,id_vars=["Date","Drug_name","Parameter"],var_name="Time",value_name="Result")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-764959ddb927> in <module>
# ----> 1 pd.melt(df,id_vars=["Date","Drug_name","Parameter"],var_name="Time",value_name="Result")
#
# /usr/local/lib/python3.8/dist-packages/pandas/core/reshape/melt.py in melt(frame, id_vars, value_vars, var_name, value_name, col_level, ignore_index)
#      80             missing = Index(com.flatten(id_vars)).difference(cols)
#      81             if not missing.empty:
# ---> 82                 raise KeyError(
#      83                     "The following 'id_vars' are not present "
#      84                     f"in the DataFrame: {list(missing)}"
#
# KeyError: "The following 'id_vars' are not present in the DataFrame: ['Drug_name']"

# %%
df_tidy.groupby("Drug_Name")["Pressure"].mean()

# %%
df_tidy.pivot_table(index="Drug_Name",
                    columns = "Date")

# %% [markdown]
# Melting

# %%
df3=({"Person":["Nikhil","Raghavraj","Aman","Narendra"],"House":["A","B","A","C"],"Age":[23,32,33,14],"Books":[102,112,133,123],"Movies":[42,20,21,65]})

# %%
df3

# %%
df3=pd.DataFrame(df3)

# %%
df3

# %%
df3.melt()

# %%
df3.melt(id_vars=["Age","Movies"],value_vars=["Person","House","Books"])

# %%
df3.melt(id_vars=["Age","Movies"],value_vars=["Person","House"])

# %%
df3.melt(id_vars=["Age","Movies"],value_vars=["Person","House","Books"],var_name="Column",value_name="Value")    #to rename variable and value column name

# %% [markdown]
# Pivoting

# %%
df4=pd.DataFrame({"fruit":["apple","orange","apple","avaconda","orange"],
                  "customer":["ben","alice","ben","josh","steve"],
                  "quantity":[1,2,3,1,2]})

# %%
df4
# Out:
#       fruit customer  quantity
# 0     apple      ben         1
# 1    orange    alice         2
# 2     apple      ben         3
# 3  avaconda     josh         1
# 4    orange    steve         2

# %%
df4.pivot_table(index="fruit",columns="customer",values="quantity",aggfunc=np.sum)
# Out:
# customer  alice  ben  josh  steve
# fruit
# apple       NaN  4.0   NaN    NaN
# avaconda    NaN  NaN   1.0    NaN
# orange      2.0  NaN   NaN    2.0

# %%
# !ls    #to see files

# %%
# !gdown https//:d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/717/original/sales_dataset.csv?1651728217
# Out:
# Access denied with the following error:
#
#  	Cannot retrieve the public link of the file. You may need to change
# 	the permission to 'Anyone with the link', or have had many accesses.
#
# You may still be able to access the file from the browser:
#
# 	 https://drive.google.com/uc?id=https//:d2beiqkhq929f0.cloudfront.net/public_assets/assets/000/003/717/original/sales_dataset.csv?1651728217

# %%
import pandas as pd
import numpy as np
sales=pd.read_csv("sales_dataset", index_col = 0)
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-4-801c92c70303> in <module>
#       1 import pandas as pd
#       2 import numpy as np
# ----> 3 sales=pd.read_csv("sales_dataset", index_col = 0)
#
# /usr/local/lib/python3.8/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
